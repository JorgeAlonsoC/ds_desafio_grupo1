# %%
import pandas as pd
url = "https://desafiogrupo1.s3.amazonaws.com/DDOS_campos_relevantes.csv.xls"
df_ddos = pd.read_csv(url, nrows= 10000)
display(df_ddos.head())
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0               389      113095465                 48                      24
# 1               389      113473706                 68                      40
# 2                 0      119945515                150                       0
# 3               443       60261928                  9                       7
# 4                53            269                  2                       2
#
#    Total Length of Fwd Packets   Flow Bytes/s Flow Packets/s  \
# 0                         9668  1.740.122.825    0.636630302
# 1                        11364  2.122.253.767     0.95176234
# 2                            0              0    125.056.781
# 3                         2330  1.087.087.688    0.265507602
# 4                          102  1.576.208.178  1.486.988.848
#
#    Fwd Packet Length Max  Fwd Packet Length Min Fwd Packet Length Mean  ...  \
# ...

# %%
df_phishing_2 = pd.read_csv('https://desafiogrupo1.s3.us-east-1.amazonaws.com/PhiUSIIL_Phishing_URL_Dataset.csv', nrows= 10000)
df_phishing_2
# Out:
#           FILENAME                                     URL  URLLength  \
# 0       521848.txt        https://www.southbankmosaics.com         31
# 1        31372.txt                https://www.uni-mainz.de         23
# 2       597387.txt          https://www.voicefmradio.co.uk         29
# 3       554095.txt             https://www.sfnmjournal.com         26
# 4       151578.txt      https://www.rewildingargentina.org         33
# ...            ...                                     ...        ...
# 9995  mw178026.txt                http://www.yucheng01.com         23
# 9996    570690.txt         https://www.luckyloucocotoo.com         30
# 9997    390601.txt             https://www.journeymart.com         26
# 9998    562779.txt  https://www.plantingseedscaribbean.com         37
# 9999    222277.txt            https://www.primalscream.net         27
#
#                               Domain  DomainLength  IsDomainIP  TLD  \
# ...

# %%
df_int_login = pd.read_csv('rba-dataset.csv', nrows= 10000, index_col=0)
df_int_login.head()
# Out:
#                Login Timestamp              User ID  Round-Trip Time [ms]  \
# index
# 0      2020-02-03 12:43:30.772 -4324475583306591935                   NaN
# 1      2020-02-03 12:43:43.549 -4324475583306591935                   NaN
# 2      2020-02-03 12:43:55.873 -3284137479262433373                   NaN
# 3      2020-02-03 12:43:56.180 -4324475583306591935                   NaN
# 4      2020-02-03 12:43:59.396 -4618854071942621186                   NaN
#
#           IP Address Country    Region       City     ASN  \
# index
# 0        10.0.65.171      NO         -          -   29695
# 1       194.87.207.6      AU         -          -   60117
# 2      81.167.144.58      NO  Vestland  Urangsvag   29695
# 3      170.39.78.152      US         -          -  393398
# 4          10.0.0.47      US  Virginia    Ashburn  398986
#
#                                        User Agent String  \
# index
# 0      Mozilla/5.0  (iPhone; CPU iPhone OS 13_4 like ...
# ...

# %%
def malware_type_detection(dict):
    if 'FILENAME' in dict.keys():
        print("Entra en el pipeline de Phishisng")
    elif 'Destination Port' in dict.keys():
        print("Entra en el pipeline de DDOS")
    else:
        print("Entra en el pipeline de Intento de login")

# %%
malware_type_detection(df_phishing_2.iloc[10].to_dict())
malware_type_detection(df_ddos.iloc[20].to_dict())
malware_type_detection(df_int_login.iloc[150].to_dict())
# Out:
# Entra en el pipeline de Phishisng
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login

# %%
df_int_login.shape
# Out:
# (10000, 15)

# %%
login_list =[]
for i in range(100):
    login_list.append(df_int_login.iloc[i].to_dict())

for i in range(100):
    login_list.append(df_ddos.iloc[i].to_dict())

for i in range(100):
    login_list.append(df_ddos.iloc[i].to_dict())

# %%
login_list[243]
# Out:
# {'Destination Port': 53,
#  'Flow Duration': 205,
#  'Total Fwd Packets': 2,
#  'Total Backward Packets': 2,
#  'Total Length of Fwd Packets': 88,
#  'Flow Bytes/s': '1.346.341.463',
#  'Flow Packets/s': '1.951.219.512',
#  'Fwd Packet Length Max': 44,
#  'Fwd Packet Length Min': 44,
#  'Fwd Packet Length Mean': '44',
#  'SYN Flag Count': 0,
#  'ACK Flag Count': 0,
#  'RST Flag Count': 0,
#  'PSH Flag Count': 0,
#  'URG Flag Count': 0,
#  'CWE Flag Count': 0,
#  'ECE Flag Count': 0,
#  'Down/Up Ratio': 1,
#  'Subflow Fwd Packets': 2,
#  'Subflow Bwd Packets': 2,
#  'Active Mean': '0',
#  'Active Max': 0,
#  'Active Min': 0,
#  'Idle Mean': '0',
#  'Idle Max': 0,
#  'Idle Min': 0}

# %%
for i in range(300):
    malware_type_detection(login_list[i])
# Out:
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# ...

# %%
import random

random.shuffle(login_list)
login_list[0]
# Out:
# {'Destination Port': 53,
#  'Flow Duration': 200,
#  'Total Fwd Packets': 2,
#  'Total Backward Packets': 2,
#  'Total Length of Fwd Packets': 88,
#  'Flow Bytes/s': '1380000',
#  'Flow Packets/s': '20000',
#  'Fwd Packet Length Max': 44,
#  'Fwd Packet Length Min': 44,
#  'Fwd Packet Length Mean': '44',
#  'SYN Flag Count': 0,
#  'ACK Flag Count': 0,
#  'RST Flag Count': 0,
#  'PSH Flag Count': 0,
#  'URG Flag Count': 0,
#  'CWE Flag Count': 0,
#  'ECE Flag Count': 0,
#  'Down/Up Ratio': 1,
#  'Subflow Fwd Packets': 2,
#  'Subflow Bwd Packets': 2,
#  'Active Mean': '0',
#  'Active Max': 0,
#  'Active Min': 0,
#  'Idle Mean': '0',
#  'Idle Max': 0,
#  'Idle Min': 0}

# %%
def procesamiento_datos():
    login_list =[]
    df_int_login = pd.read_csv("https://desafiogrupo1.s3.us-east-1.amazonaws.com/df1_alimentacion_login.csv")
    df_ddos = pd.read_csv("https://desafiogrupo1.s3.us-east-1.amazonaws.com/df_alimentacion_DDOS.csv")
    df_phishing = pd.read_csv("https://desafiogrupo1.s3.us-east-1.amazonaws.com/df_alimentacion_phising.csv")

    for i in range(df_int_login.shape[0]):
        login_list.append(df_int_login.iloc[i].to_dict())

    for i in range(df_ddos.shape[0]):
        login_list.append(df_ddos.iloc[i].to_dict())

    for i in range(df_phishing.shape[0]):
        login_list.append(df_phishing.iloc[i].to_dict())

    random.shuffle(login_list)

    for i in range(len(login_list)):
        malware_type_detection(login_list[i])

# %%
procesamiento_datos()
# Out:
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Phishisng
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Phishisng
# Entra en el pipeline de Intento de login
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login
# Entra en el pipeline de DDOS
# Entra en el pipeline de DDOS
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de DDOS
# Entra en el pipeline de DDOS
# Entra en el pipeline de DDOS
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# Entra en el pipeline de Intento de login
# ...
