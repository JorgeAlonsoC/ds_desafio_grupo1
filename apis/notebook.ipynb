# %%
import pandas as pd

# Link en el AWS: Propiedades > URL del objeto
url1 = "https://desafiogrupo1.s3.us-east-1.amazonaws.com/phishing.json"
df1 = pd.read_json(url1)
df1.head()
# Out:
#                                     _id                  domain_name  \
# 0  {'$oid': '662ef11c9c88568844e38f1a'}            conflrma57843.com
# 1  {'$oid': '660caa1a528344e2948e0c13'}              www.zgahdjm.com
# 2  {'$oid': '65c4d948ec20407e161504ca'}               attt.pages.dev
# 3  {'$oid': '65d75308bdfee21c31b781fa'}      chermate.weeblysite.com
# 4  {'$oid': '660f4d1a528344e29492a240'}  allegrolokalnie.oferta73.pl
#
#    category                                                dns  \
# 0  phishing  {'A': ['188.114.97.9', '188.114.96.9'], 'AAAA'...
# 1  phishing  {'A': None, 'AAAA': None, 'CNAME': None, 'MX':...
# 2  phishing  {'A': ['172.66.44.147', '172.66.47.109'], 'AAA...
# 3  phishing  {'A': ['162.159.140.60', '172.66.0.60'], 'AAAA...
# 4  phishing  {'A': ['84.32.84.33'], 'AAAA': None, 'CNAME': ...
#
#                             evaluated_on  \
# 0  {'$date': '2024-04-29T03:19:57.352Z'}
# 1  {'$date': '2024-04-03T03:14:49.179Z'}
# 2  {'$date': '2024-01-30T11:02:40.844Z'}
# 3  {'$date': '2023-11-20T18:17:45.439Z'}
# 4   {'$date': '2024-04-05T03:12:20.41Z'}
#
#                                              ip_data                label  \
# 0  [{'ip': '188.114.97.9', 'from_record': 'A', 'r...  phishing_since_2402
# 1                                               None  phishing_since_2402
# 2  [{'ip': '2606:4700:310c::ac42:2f6d', 'from_rec...  phishing_since_2402
# 3  [{'ip': '172.66.0.60', 'from_record': 'A', 're...  phishing_since_2402
# 4  [{'ip': '84.32.84.33', 'from_record': 'A', 're...  phishing_since_2402
#
#                                                 rdap  \
# 0  {'handle': '2876141922_DOMAIN_COM-VRSN', 'name...
# 1  {'handle': '', 'name': 'zgahdjm.com', 'whois_s...
# 2  {'handle': '', 'name': 'pages.dev', 'whois_ser...
# 3  {'handle': '', 'name': 'weeblysite.com', 'whoi...
# 4  {'handle': '', 'name': 'oferta73.pl', 'whois_s...
#
#                                              remarks     source  \
# 0  {'dns_evaluated_on': {'$date': '2024-04-29T03:...  openphish
# 1  {'dns_evaluated_on': {'$date': '2024-04-03T03:...  phishtank
# 2  {'dns_evaluated_on': {'$date': '2024-01-30T11:...  phishtank
# 3  {'dns_evaluated_on': {'$date': '2023-11-20T18:...  phishtank
# 4  {'dns_evaluated_on': {'$date': '2024-04-05T03:...  phishtank
#
#                               sourced_on  \
# 0  {'$date': '2024-04-29T03:00:12.351Z'}
# 1  {'$date': '2024-04-03T03:00:08.447Z'}
# 2  {'$date': '2024-01-30T09:31:01.663Z'}
# 3  {'$date': '2023-11-20T17:36:44.311Z'}
# 4  {'$date': '2024-04-05T03:00:08.815Z'}
#
#                                                  tls  \
# 0  {'cipher': 'TLS_AES_256_GCM_SHA384', 'count': ...
# 1  {'cipher': 'TLS_AES_256_GCM_SHA384', 'count': ...
# 2  {'cipher': 'TLS_AES_256_GCM_SHA384', 'count': ...
# 3  {'cipher': 'TLS_AES_256_GCM_SHA384', 'count': ...
# 4                                               None
#
#                                                  url
# 0              https://conflrma57843.com/u6383644457
# 1                            https://www.zgahdjm.com
# 2                            https://attt.pages.dev/
# 3                   https://chermate.weeblysite.com/
# 4  https://allegrolokalnie.oferta73.pl/oferta/l/i...
